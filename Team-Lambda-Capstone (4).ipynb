# %% [markdown]
# # Team Lambda Capstone Project
#
# Benjamin Houldridge
#
# Catherine Laguna
#
# Elija Martin

# %% [markdown]
# ##Problem Definition

# %% [markdown]
# ##Data Collection and Sorces

# %% [markdown]
# ### Imports

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
import sklearn.model_selection as model_selection
from IPython.display import Image
import statsmodels.api as sm
from sklearn import preprocessing
import json
import xgboost as xgb
from sklearn.model_selection import train_test_split
import pickle
from textblob import TextBlob as tb
from textblob import Word
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###Read In Datasets

# %%
lib1720_path = '/content/drive/My Drive/Team Lambda/Data/2017-2019.csv'
lib19_path = '/content/drive/My Drive/Team Lambda/Data/2019.csv'
lib20_path = '/content/drive/My Drive/Team Lambda/Data/2020.csv'
lib17_path = '/content/drive/My Drive/Team Lambda/Data/2017.csv'
lib1417_path = '/content/drive/My Drive/Team Lambda/Data/2014-2017.csv'

# %%
nlp1720 = pd.read_csv(lib1720_path,encoding = "ISO-8859-1")

# %%
nlp19 = pd.read_csv(lib19_path, encoding = "ISO-8859-1")

# %%
nlp20 = pd.read_csv(lib20_path, encoding = "ISO-8859-1")

# %%
nlp17 = pd.read_csv(lib17_path, encoding = "ISO-8859-1")

# %%
nlp1417 = pd.read_csv(lib1417_path, encoding = "ISO-8859-1")

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# ###Fill in Missing Bootcamp

# %% [markdown]
# nlp17 and npl1417 data all comes from the fullstack web development couse. This information was not included in the datasets and so needed to be added.

# %%
nlp17['Which bootcamp did you attend?'] = 'Fullstack Web Development'
nlp1417['Which bootcamp did you attend?'] = 'Fullstack Web Development'

# %% [markdown]
# Some rows where missing information about which bootcamp was attended. Andrea Sisneros Wichman provided the missing information.

# %%
nlp19.loc[30,'Which bootcamp did you attend?'] = 'Fullstack Web Development'
nlp20.loc[23,'Which bootcamp did you attend?'] = 'Internet of Things (IoT)'
nlp20.loc[25,'Which bootcamp did you attend?'] = 'Internet of Things (IoT)'
nlp20.loc[42,'Which bootcamp did you attend?'] = 'Digital Media'
nlp20.loc[54,'Which bootcamp did you attend?'] = 'Fullstack Web Development'

# %% [markdown]
# ###Synchronization of Column Names

# %% [markdown]
# To create unified column names that will adhere to each question, the column names for each dataset will be redefined. Below is a set of dictionaries that map the old column names to new codes that represent each unique question. The first two smaller dictionaries exist because some of the data sets share the same column names but they correspond to different questions. The two smaller dictionaries will change a few of the names on their respective datasets then the large dictionary will be ran on all datasets to produce unified column names.

# %%
column_names_mapped_nlp19 = {
    'Unnamed: 35': 'p14_s_r',
    'Unnamed: 43': 'qsue_r',
    'Unnamed: 47': 'qstem_r'
}

column_names_mapped_nlp20 = {
    'Unnamed: 35': 'p14_s_r',
    'Unnamed: 37': 'q14_1_r',
    'Unnamed: 43': 'qsue_r',
    'Unnamed: 47': 'qeste_r'
}

column_names_mapped_nlp1417 = {
    'Unnamed: 35': 'q_s_5_r',
    'Unnamed: 37': 'q_s_6_r'
}

column_names_mapped_nlp17 = {
    'Unnamed: 13': 'q4_r',
    'Unnamed: 15': 'q5_r',
    'Unnamed: 17': 'q6_r',
    'Unnamed: 19': 'q7_r',
    'Unnamed: 21': 'q8_r',
    'Unnamed: 29': 'q12_r',
    'Unnamed: 31': 'q1_r'
}

# %%
column_names_mapped = {
    'Which bootcamp did you attend?':'q1',
    'Would you recommend this course to others?':'q1_1',
    'Unnamed: 10':'q1_r',
    'I understood the goals and objectives of this course when it began:':'q2',
    'Unnamed: 12': 'q2_r',
    'The goals and objectives of this course, as I understand them, are met at this time:': 'q3',
    'Unnamed: 14': 'q3_r',
    'The requirements and grading system for the course were clear:': 'q4',
    'Unnamed: 16': 'q4_r',
    'The instructors treated me with respect:': 'q5',
    'Unnamed: 18': 'q5_r',
    'The instructors were available to help when asked:': 'q6',
    'Unnamed: 20': 'q6_r',
    'The instructors were knowledgeable about the course material:': 'q7',
    'Unnamed: 22': 'q7_r',
    'The instructors were organized and prepared:': 'q8',
    'Unnamed: 24': 'q8_r',
    'I am satisfied with the format of the instruction:': 'q9',
    'Unnamed: 26': 'q9_r',
    'The pace of the course was conducive to my learning:': 'q10',
    'Unnamed: 28': 'q10_r',
    'The level of the course material was conducive to my learning:': 'q11',
    'Unnamed: 30': 'q11_r',
    'On average, how many hours per week have you spent, outside of the classroom, on this course?': 'q12',
    'Unnamed: 32': 'q12_r',
    'Are there any changes you would recommend for this course?': 'q13_r',
    'Did you have any concerns before beginning the bootcamp and if so, were those concerns alleviated?': 'q14',
    'Unnamed: 35': 'q14_r',
    'Who challenged you the most?': 'q15_r',
    'Who made you feel the most comfortable?': 'q16_r',
    'Who was your favorite guest instructor or speaker? Why?': 'q17_r',
    'Who was your LEAST favorite guest instructor or speaker? Why?': 'q18_r',
    'I had a good experience with myåÊBootcamp Success Manager (Sue):': 'qsue',
    'Unnamed: 41': 'qsue_r',
    'I had a good experience withåÊmy Pro Dev instructor (Daniel):': 'qdan',
    'Unnamed: 43': 'qdan_r',
    'I had a good experience with the Program Manager (Devonna):': 'qdev',
    'Unnamed: 45': 'qdev_r',
    'The STEMulus Center provided an effective learning environment:': 'qstem',
    'Unnamed: 47': 'q22_r',
    'Would you like to leave a review about your bootcamp experience?åÊIf so, please write a short testimonial. It may be used for our marketing purposes.': 'q23_r',
    'One a scale of 1-10, 1 being lowest and 10 highest, how likely areåÊyou toåÊ recommend this course to others?':'q1_1',
    'Did you have any concerns before beginning the bootcamp?': 'q14_s',
    'If you did have concerns before beginning the bootcamp, were those concerns alleviated?': 'q14_1',
    'Unnamed: 37' : 'q14_1_1',
    'Respondent ID': 'Respondent ID',
    'Collector ID': 'Collector ID',
    'Start Date': 'Start Date',
    'End Date': 'End Date',
    'Email Address': 'Email Address',
    'First Name': 'First Name',
    'Last Name': 'Last Name',
    'Custom Data 1': 'Custom Data 1',
    'I had a good experience with the Employer Relations Manager (Esteban):': 'qeste',
    'Unnamed: 49':'qstem_r',
    'Unnamed: 9' : 'q2_r',
    'Unnamed: 11' : 'q3_r',
    'Unnamed: 13' : 'q5_r',
    'Unnamed: 15' : 'q4_r',
    'Unnamed: 17' : 'q_s_1_r',
    'Unnamed: 19' : 'q6_s_r',
    'Unnamed: 21' : 'q8_s_r',
    'Unnamed: 23' : 'q9_r',
    'Unnamed: 25' : 'q10_r',
    'Unnamed: 27' : 'q11_r',
    'Unnamed: 29' : 'q_s_2_r',
    'Unnamed: 31' : 'q_s_3_r',
    'Unnamed: 34' : 'q14_r',
    'I had a good experience with my Student Success Specialist (Karen):' : 'qkar',
    'Unnamed: 38' : 'qkar_r',
    'I had a good experience with my Career Coach (Daniel):' : 'qdan',
    'Unnamed: 40' : 'qdan_r',
    'I had a good experience with the Senior Program Manager (Andrea):' : 'qand',
    'Unnamed: 42' : 'qand_r',
    'Unnamed: 44' : 'qstem_r',
    'Would you like to leave a testimonial? If we may use it for marketing purposes, please include your name.åÊ' : 'q23_r',
    'I understood the goals/objective of this course at the beginning of the course:' : 'q2',
    'The goals/objective of this course, as I understand them, are met at this time:' : 'q3',
    'My instructor treated me with respect:' : 'q5',
    'I felt free to ask questions in the course:' : 'q_s_1',
    'The instructor answered my questions when I asked them:' : 'q6_s',
    "The instructor's course presentations were organized:" : 'q8_s',
    'The textbook helped me to learn:' : 'q_s_2',
    'Homework assignments helped me better understand the course material:' : 'q_s_3',
    'The instructor was willing to work with me outside of the class:' : 'q_s_4',
    'Unnamed: 33' : 'q_s_4_r',
    'The instructor evaluated my learning based on course material presented and course requirements:' : 'q_s_5',
    'I have become more competent in this area due to this course:' : 'q_s_6',
    'Unnamed: 39' : 'q12_r',
    'List one or more aspects of the course that you liked:' : 'q_s_7_r'

    }

# %% [markdown]
# The above dictionary needs to be checked for human error. To test the above dictionary we need to make sure that all current column names are mapped to their new code. The below function will affirm that all column names in a given column have a mapping and return any that have been missed.

# %%
def check_column_names(dataframe):
  """Check if all column names in dataframe are in the dictionary as keys."""

  output = []
  for column in dataframe.columns:
    if column in column_names_mapped:
      continue
    else:
      output.append(column)
  if len(output) == 0:
    return 'All column names are found in dictionary'
  else:
    return output

# %%
check_column_names(nlp1720)
check_column_names(nlp19)
check_column_names(nlp20)
check_column_names(nlp17)
check_column_names(nlp1417)
# Out:
# 'All column names are found in dictionary'

# %% [markdown]
# Rename the columns in all datasets using the above mapping.

# %%
nlp19.rename(column_names_mapped_nlp19, axis= 1, inplace=True)
nlp20.rename(column_names_mapped_nlp20, axis= 1, inplace=True)
nlp17.rename(column_names_mapped_nlp17, axis= 1, inplace=True)
nlp1417.rename(column_names_mapped_nlp1417, axis= 1, inplace=True)
nlp19.rename(column_names_mapped, axis= 1, inplace=True)
nlp20.rename(column_names_mapped, axis= 1, inplace=True)
nlp1720.rename(column_names_mapped, axis= 1, inplace=True)
nlp17.rename(column_names_mapped, axis= 1, inplace=True)
nlp1417.rename(column_names_mapped, axis= 1, inplace=True);

# %% [markdown]
# Check if all column names are mapped to codes.

# %%
print(nlp1720.columns)
print(nlp19.columns)
print(nlp20.columns)
print(nlp17.columns)
print(nlp1417.columns)
# Out:
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q1',
#        'q1_1', 'q1_r', 'q2', 'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r',
#        'q6', 'q6_r', 'q7', 'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r',
#        'q11', 'q11_r', 'q12', 'q12_r', 'q13_r', 'q14', 'q14_r', 'q15_r',
#        'q16_r', 'q17_r', 'q18_r', 'qsue', 'qsue_r', 'qdan', 'qdan_r', 'qdev',
#        'qdev_r', 'qstem', 'q22_r', 'q23_r'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q1',
#        'q1_1', 'q1_r', 'q2', 'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r',
#        'q6', 'q6_r', 'q7', 'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r',
#        'q11', 'q11_r', 'q12', 'q12_r', 'q13_r', 'q14_s', 'p14_s_r', 'q14_1',
#        'q14_1_1', 'q15_r', 'q16_r', 'q17_r', 'q18_r', 'qsue', 'qsue_r', 'qdev',
#        'qdev_r', 'qstem', 'qstem_r', 'q23_r'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q1',
#        'q1_1', 'q1_r', 'q2', 'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r',
#        'q6', 'q6_r', 'q7', 'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r',
#        'q11', 'q11_r', 'q12', 'q12_r', 'q13_r', 'q14_s', 'p14_s_r', 'q14_1',
#        'q14_1_r', 'q15_r', 'q16_r', 'q17_r', 'q18_r', 'qsue', 'qsue_r', 'qdev',
#        'qdev_r', 'qeste', 'qeste_r', 'qstem', 'qstem_r', 'q23_r'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q2',
#        'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r', 'q6', 'q6_r', 'q7',
#        'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r', 'q11', 'q11_r',
#        'q12', 'q12_r', 'q1_1', 'q1_r', 'q13_r', 'q14', 'q14_r', 'q15_r',
#        'q16_r', 'qkar', 'qkar_r', 'qdan', 'qdan_r', 'qand', 'qand_r', 'qstem',
#        'qstem_r', 'q23_r', 'q1'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q2',
#        'q2_r', 'q3', 'q3_r', 'q5', 'q5_r', 'q4', 'q4_r', 'q_s_1', 'q_s_1_r',
#        'q6_s', 'q6_s_r', 'q8_s', 'q8_s_r', 'q9', 'q9_r', 'q10', 'q10_r', 'q11',
#        'q11_r', 'q_s_2', 'q_s_2_r', 'q_s_3', 'q_s_3_r', 'q_s_4', 'q_s_4_r',
#        'q_s_5', 'q_s_5_r', 'q_s_6', 'q_s_6_r', 'q12', 'q12_r', 'q_s_7_r',
#        'q13_r', 'q1'],
#       dtype='object')

# %% [markdown]
# Append the three data sets into one unified data frame.

# %%
combined_data = nlp1720.append([nlp19, nlp20, nlp17, nlp1417], ignore_index=True, sort=True)
combined_data.head()
# Out:
#    Collector ID  ...                                             qsue_r
# 0           NaN  ...                             Other (please specify)
# 1   175557115.0  ...  I am so happy Sue joined during our cohort! Sh...
# 2   175557115.0  ...                                                NaN
# 3   175557115.0  ...                                                NaN
# 4   175557115.0  ...                                    Sue's awesome.
#
# [5 rows x 78 columns]

# %% [markdown]
# ###Extract Year of Survey from EndDate
# In order to evaluate sentiment <b> over time </b> need a time stamp in the dataframe. Will extract year from 'End Date' field. 'End Date' field only demarks when survey was completed but for our purposes will work.

# %%
#create a new column that contains year in 'End Date'
for each in range(len(combined_data['End Date'])):
  combined_data['year']=pd.DatetimeIndex(combined_data['End Date']).year
combined_data['year'].value_counts()
# Out:
# 2019.0    100
# 2018.0     75
# 2020.0     58
# 2017.0     28
# 2015.0     16
# 2016.0     12
# 2014.0     10
# Name: year, dtype: int64

# %% [markdown]
# ###Delete Useles Columns and Rows

# %% [markdown]
# Drop unusable columns, and top row.

# %%
combined_data.drop(['Collector ID', 'Custom Data 1', 'Email Address', 'End Date', 'First Name', 'Last Name', 'Respondent ID', 'Start Date', 'qkar_r', 'qand_r'], axis=1, inplace=True)

# %% [markdown]
# Drop unusable rows.

# %%
hedder_rows = combined_data[combined_data['q3']=='Response'].index

# %%
combined_data.drop(hedder_rows, axis=0, inplace=True)

# %% [markdown]
# Reindex

# %%
combined_data.reset_index(drop=True, inplace=True)

# %% [markdown]
# ###Clean Individual Columns

# %% [markdown]
# q12 > "On average, how many hours per week have you spent, outside of the classroom, on this course? Responses (field values) were ugly which required specific coding.

# %%
# collect list of bad strings
bad_str=combined_data['q12'].unique()
bad_str
# Out:
# array(['10-Jun', '16åÊ- 20', '15-Nov', '0 - 5', '20+', '4.1 - 6', '8+',
#        '6.1 - 8', '0 - 2', '2.1 - 4'], dtype=object)

# %%
# check each unique value and replace with
# convert to label encoding

def interpret_q12():
  """Takes the stings given in the q12 column and returns a new series with usable entries"""

  bad_str=combined_data['q12'].unique().copy()
  x = pd.Series(np.zeros(combined_data.shape[0]))
  for idx,item in enumerate(combined_data['q12']):
    if item not in bad_str:
      continue
    elif item == '10-Jun' or item=='0 - 5' or item == '4.1 - 6' or item=='8+' or item=='6.1 - 8' or item=='0 - 2' or item=='2.1 - 4':
      x[idx]='less than 10h'
    elif item =='15-Nov':
      x[idx]='10h - 15h'
    elif item == '16åÊ- 20':
      x[idx]='15h - 20h'
    elif item == '20+':
      x[idx]= 'greater than 20h'
  return x

# %%
interpret_q12().unique()
# Out:
# array(['less than 10h', '15h - 20h', '10h - 15h', 'greater than 20h'],
#       dtype=object)

# %%
combined_data['q12'] = interpret_q12()

# %% [markdown]
# q1_1 conversion

# %% [markdown]
# Given the three datasets: nlp1720, nlp19, nlp20, there was a change to how responses were requested from binary (Y,N) to a Likert scale (1 - 10) for the question "Would you recommend this course to others?"
#
# To address these differences it was decided to collapse the Likert scale into a Binary pattern.
#
# | Likert Scale | Binary Value |
# |-|-|
# | <=5 |	N |
# | >5 |	Y |

# %%
combined_data['q1_1'].fillna('No Response', inplace=True)

# %%
combined_data['q1_1'].unique()
# Out:
# array(['Yes', 'No Response', 'No', '9', '10', '8', '7', '2', '4', '5',
#        '3', '6'], dtype=object)

# %%
for idx,item in enumerate(combined_data['q1_1']):
  if item=='Yes' or item=='No' or item=='No Response':
    continue
  elif int(item)>5:
    combined_data['q1_1'][idx]='Yes'
  else:
    combined_data['q1_1'][idx] ='No'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
combined_data['q1_1'].unique()
# Out:
# array(['Yes', 'No Response', 'No'], dtype=object)

# %% [markdown]
# ###Fill Nan values wtih 'No Response'

# %%
clean_data = combined_data.fillna('No Response').copy()

# %% [markdown]
# Reset index

# %%
clean_data.reset_index(drop=True, inplace=True)

# %%
clean_data.head()
# Out:
#        p14_s_r  ...    year
# 0  No Response  ...  2019.0
# 1  No Response  ...  2019.0
# 2  No Response  ...  2019.0
# 3  No Response  ...  2019.0
# 4  No Response  ...  2019.0
#
# [5 rows x 69 columns]

# %% [markdown]
# ###Spell Check

# %%
clean_data['q2_r']
# Out:
# 0      They were clearly stated and with such an exte...
# 1                                            No Response
# 2                                            No Response
# 3                                            No Response
# 4                                            No Response
#                              ...
# 294                                          No Response
# 295                                          No Response
# 296                                          No Response
# 297                                          No Response
# 298                                          No Response
# Name: q2_r, Length: 299, dtype: object

# %%
for entry in clean_data['q2_r']:
  if entry == 'No Response':
    continue
  else:
    sentence = tb(entry)
    if sentence.correct() == sentence:
      continue
    else:
      print(sentence)
      print(sentence.correct())
# Out:
# Sorta.. I probably should've done more research before signing up to this specific course. I'm definitely glad I finished, though!
# Aorta.. I probably should've done more research before signing up to this specific course. I'm definitely glad I finished, though!
# Adobe was mentioned, and that we would be doing a bit of game design.
# Done was mentioned, and that we would be doing a bit of game design.
# I thought I did understand in a general sort of way, but I wish that the reality of what a fullstack developer is, what a "win" or "success" at the bootcamp looks like, since I spent a large amount of time convinced that I was a failure, along with all the other bootcamp attendees
# I thought I did understand in a general sort of way, but I wish that the reality of what a fullstack developer is, what a "win" or "success" at the bootcamp looks like, since I spent a large amount of time convinced that I was a failure, along with all the other bootcamp attended
# The director and instructors made it very clear of the dynamics of the course and what to expect.
# The director and instructor made it very clear of the dynamic of the course and what to expect.
# I would have liked to know more about the personal domains and personal servers before spending money on them.
# I would have liked to know more about the personal domain and personal serves before spending money on them.
# I did a lot of research into bootcamps before I applied and chose CNM's bootcamp specifically because its curriculum seemed better than dozens of other options.
# I did a lot of research into bootcamps before I applied and chose CNM's bootcamp specifically because its curriculum seemed better than dozens of other option.
# It took a few weeks to fully realize the point is to learn the basics, not full depth of JS.
# It took a few weeks to fully realize the point is to learn the basis, not full depth of of.
# Everything was outline and explained prior to starting the camp. No secrets on its intensity and difficulty !
# Everything was outline and explained prior to starting the camp. To secrets on its intensity and difficulty !
# I had assumed there would be more javascript but it felt too php heavy.
# I had assumed there would be more javascript but it felt too pp heavy.
# Majority of the time I did this course is fast past for me, but helped me to think like a programmer
# Majority of the time I did this course is fast past for me, but helped me to think like a programme
# The whole course needs much much better documentation and hard deadlines. I was the only person finished with my PWP on time and left starting the front end of the capstone by myself. Of course, when I did it wrong it was all my fault. LawL! On the positive I learned more about   AngularJS than I would have otherwise.
# The whole course needs much much better documentation and hard deadline. I was the only person finished with my PWP on time and left starting the front end of the capstone by myself. Of course, when I did it wrong it was all my fault. saw! In the positive I learned more about   AngularJS than I would have otherwise.
# The course spent 90% of the instructional period on the backend PHP stuff.  This was useful and is helping me in the "real world" but I went into it expecting to come out 100% competent in front end development as well.    My other classmates have all said essentially the same thing to me; that we had far too little quality front end development and design instruction.  I learned the overwhelming majority of front end from reading the class materials and feel rather short changed on actual instruction in that area.
# The course spent 90% of the instructions period on the backed PHP stuff.  His was useful and is helping me in the "real world" but I went into it expecting to come out 100% competent in front end development as well.    By other classmates have all said essentially the same thing to me; that we had far too little quality front end development and design instruction.  I learned the overwhelming majority of front end from reading the class materials and feel rather short changed on actual instruction in that area.
# However, the emphasis of backend vs frontend development should be stressed
# However, the emphasis of backed vs fronted development should be stressed
# I understood the course as one that would teach me the fundamentals of 5 different computer languages, with a nearly guaranteed job upon completion.   While I did NOT expect to walk directly into a job, I know of several students who did have that expectation, and who are currently disappointed.  As for learning the fundamentals of the 5 languages -- well, I THOUGHT I had a good start on all five, as I'd already completed regular courses in a couple of the subjects, and have an inclination for languages, including computer code.  It would have been more appropriate to advertise this course as an intense "introduction" to five different languages -- and to let students know many hours of extra study would be required to attain a minimal proficiency in the subjects.
# I understood the course as one that would teach me the fundamentals of 5 different computer languages, with a nearly guaranteed job upon completion.   While I did NOT expect to walk directly into a job, I know of several students who did have that expectation, and who are currently disappointed.  Is for learning the fundamentals of the 5 languages -- well, I THOUGHT I had a good start on all five, as I'd already completed regular courses in a couple of the subjects, and have an inclination for languages, including computer code.  It would have been more appropriate to advertise this course as an intense "introduction" to five different languages -- and to let students know many hours of extra study would be required to attain a minimal proficient in the subjects.

# %%
for entry in clean_data['q2_r']:
  cell = entry.split()
  for word in cell:
    curent_word = Word(word)
    confidence = int(curent_word.spellcheck()[0][1])
    if confidence >= .8:
      continue
    else:
      print(curent_word.spellcheck())
# Out:
# [('They', 0.997467071935157), ('Hey', 0.0025329280648429585)]
# [('time', 0.8657984144960362), ('times', 0.13363533408833522), ('timed', 0.0005662514156285391)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('weeks', 0.5518867924528302), ('week', 0.4481132075471698)]
# [('nice', 0.9814814814814815), ('nicer', 0.018518518518518517)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('on', 0.6632388178913738), ('one', 0.3365615015974441), ('ont', 9.984025559105431e-05), ('ong', 9.984025559105431e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('Sorta..', 0.0)]
# [("should've", 0.0)]
# [('course', 0.9773869346733668), ('courses', 0.022613065326633167)]
# [('him', 0.7570932252460915), ('am', 0.10799073537927041), ('arm', 0.03792704111175449), ('m', 0.02460914881297047), ('tm', 0.018529241459177764), ('aim', 0.01563404748118124), ('sum', 0.007672264041690793), ('dam', 0.004342790966994789), ('hum', 0.0036189924724956573), ('dim', 0.003474232773595831), ('rum', 0.002460914881297047), ('ulm', 0.0017371163867979154), ('hm', 0.0014475969889982628), ('dem', 0.0011580775911986102), ('ram', 0.001013317892298784), ('grm', 0.001013317892298784), ('sam', 0.0008685581933989577), ('ham', 0.0008685581933989577), ('gum', 0.0008685581933989577), ('em', 0.0007237984944991314), ('tom', 0.0005790387955993051), ('rim', 0.0005790387955993051), ('jem', 0.0005790387955993051), ('hem', 0.0005790387955993051), ('com', 0.0005790387955993051), ('jam', 0.00043427909669947886), ('gem', 0.00043427909669947886), ('wm', 0.00028951939779965256), ('nom', 0.00028951939779965256), ('jim', 0.00028951939779965256), ('dum', 0.00028951939779965256), ('cm', 0.00028951939779965256), ('zum', 0.00014475969889982628), ('tim', 0.00014475969889982628), ('pm', 0.00014475969889982628), ('om', 0.00014475969889982628), ('nm', 0.00014475969889982628), ('mmm', 0.00014475969889982628), ('mm', 0.00014475969889982628), ('km', 0.00014475969889982628), ('ism', 0.00014475969889982628), ('htm', 0.00014475969889982628), ('elm', 0.00014475969889982628), ('cum', 0.00014475969889982628)]
# [('thought', 0.5811855670103093), ('though', 0.41881443298969073)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('Done', 0.856), ('Dose', 0.05), ('Globe', 0.032), ('Probe', 0.03), ('Adore', 0.008), ('Dove', 0.006), ('Dome', 0.006), ('Robe', 0.004), ('Doze', 0.004), ('Dole', 0.002), ('Doe', 0.002)]
# [('design', 0.5161290322580645), ('designs', 0.4838709677419355)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# ...
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('It', 0.5632250580046404), ('At', 0.3580995570554735), ('T', 0.06950010546298249), ('St', 0.007751529213246151), ('Et', 0.0010018983336848766), ('Ut', 0.0002109259649862898), ('Ft', 0.0001054629824931449), ('Tt', 5.273149124657245e-05), ('Mt', 5.273149124657245e-05)]
# [('basis', 0.8333333333333334), ('basic', 0.125), ('basins', 0.041666666666666664)]
# [('JS.', 0.0)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('To', 0.7805182471849138), ('So', 0.0818613485280152), ('No', 0.06370913037579705), ('Do', 0.04078144078144078), ('Go', 0.02455569122235789), ('O', 0.006973273639940307), ('Co', 0.000814000814000814), ('Oo', 0.0002442002442002442), ('Ho', 0.0002442002442002442), ('Fo', 0.0001085334418667752), ('Po', 8.14000814000814e-05), ('Wo', 2.71333604666938e-05), ('Vo', 2.71333604666938e-05), ('Mo', 2.71333604666938e-05), ('Lo', 2.71333604666938e-05)]
# [('technologies', 0.0)]
# [('course', 0.9773869346733668), ('courses', 0.022613065326633167)]
# [('all', 0.9975926817525277), ('ally', 0.002407318247472316)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-fbd7af95e4d7> in <module>()
#       7       continue
#       8     else:
# ----> 9       print(curent_word.spellcheck())
#
# /usr/local/lib/python3.6/dist-packages/textblob/blob.py in spellcheck(self)
#     117         .. versionadded:: 0.6.0
#     118         '''
# --> 119         return suggest(self.string)
#     120
#     121     def correct(self):
#
# /usr/local/lib/python3.6/dist-packages/textblob/en/__init__.py in suggest(w)
#     121     """ Returns a list of (word, confidence)-tuples of spelling corrections.
#     122     """
# --> 123     return spelling.suggest(w)
#     124
#     125 def polarity(s, **kwargs):
#
# /usr/local/lib/python3.6/dist-packages/textblob/_text.py in suggest(self, w)
#    1396         candidates = self._known([w]) \
#    1397                   or self._known(self._edit1(w)) \
# -> 1398                   or self._known(self._edit2(w)) \
#    1399                   or [w]
#    1400         candidates = [(self.get(c, 0.0), c) for c in candidates]
#
# /usr/local/lib/python3.6/dist-packages/textblob/_text.py in _edit2(self, w)
#    1373         # Of all spelling errors, 99% is covered by edit distance 2.
#    1374         # Only keep candidates that are actually known words (20% speedup).
# -> 1375         return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#    1376
#    1377     def _known(self, words=[]):
#
# /usr/local/lib/python3.6/dist-packages/textblob/_text.py in <genexpr>(.0)
#    1373         # Of all spelling errors, 99% is covered by edit distance 2.
#    1374         # Only keep candidates that are actually known words (20% speedup).
# -> 1375         return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#    1376
#    1377     def _known(self, words=[]):
#
# /usr/local/lib/python3.6/dist-packages/textblob/_text.py in _edit1(self, w)
#    1364             [a + b[1] + b[0] + b[2:] for a, b in split if len(b) > 1],
#    1365             [a + c + b[1:] for a, b in split for c in Spelling.ALPHA if b],
# -> 1366             [a + c + b[0:] for a, b in split for c in Spelling.ALPHA]
#    1367         )
#    1368         return set(delete + transpose + replace + insert)
#
# /usr/local/lib/python3.6/dist-packages/textblob/_text.py in <listcomp>(.0)
#    1364             [a + b[1] + b[0] + b[2:] for a, b in split if len(b) > 1],
#    1365             [a + c + b[1:] for a, b in split for c in Spelling.ALPHA if b],
# -> 1366             [a + c + b[0:] for a, b in split for c in Spelling.ALPHA]
#    1367         )
#    1368         return set(delete + transpose + replace + insert)
#
# KeyboardInterrupt:

# %%
x = Word('No Respoonce')
x.spellcheck()

# %% [markdown]
# ##Exploratory Data Analysis

# %%
nlp20[0:2]

# %%
nlp1720.shape

# %%
nlp19.shape

# %%
nlp20.shape

# %% [markdown]
# ###Bootcamp Distribution --- Done

# %%
column_names_mapped['Which bootcamp did you attend?']

# %%
#Bootcamp set
a=nlp1720['q1'].value_counts()
b=nlp19['q1'].value_counts()
c=nlp20['q1'].value_counts()

# %%
#Concatenate all three lists together
bootcamps=pd.concat([a, b, c], axis=1)

# %%
# Replace NAN and get total responses for each bootcamp
bootcamps=bootcamps.fillna(0)
bootcamps.loc[:,'Total']=bootcamps.sum(axis=1)

# %%
# Cleanup result
bootcamps_clean=bootcamps.drop(['q1'], axis=1, inplace=True)
bootcamps=bootcamps.drop(labels=['Response'], axis=0)

# %%
bootcamps

# %% [markdown]
# ### Addressing "Recommend" Responses

# %% [markdown]
# Given the three datasets: nlp1720, nlp19, nlp20, there was a change to how responses were requested from binary (Y,N) to a Likert scale (1 - 10) for the question "Would you recommend this course to others?"
#
# To address these differences it was decided to collapse the Likert scale into a Binary pattern.
#
# |Likert Scale <br>value| Binary <br>value|
# |-|-|
# | <=5 | N |
# | >5 | Y|
#
# To apply, a function will be constructed to perform the translation.

# %% [markdown]
# ##Function to convert Likert to Binary

# %% [markdown]
# Determining distribution of responses on question
# nlp1720: q1_1

# %%
column_names_mapped['Would you recommend this course to others?']

# %%
nlp1720['q1_1'].value_counts()

# %%
column_names_mapped['One a scale of 1-10, 1 being lowest and 10 highest, how likely areåÊyou toåÊ recommend this course to others?']

# %%
nlp19['q1_1'].value_counts()

# %%
nlp20['q1_1'].value_counts()

# %%
#review specific NO responses
nlp1720[nlp1720['q1_1']=='No']

# %%
# review low - below 5 responses
nlp19[nlp19['q1_1']=='4']

# %%
nlp20[nlp20['q1_1']=='5']

# %% [markdown]
# ##Data Proccessing

# %% [markdown]
# ##Data Visualization
