# %% [markdown]
# # Team Lambda Capstone Project
#
# Benjamin Houldridge
#
# Catherine Laguna
#
# Elija Martin

# %% [markdown]
# ##Data Collection and Sorces

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
import sklearn.model_selection as model_selection
from IPython.display import Image
import statsmodels.api as sm
from sklearn import preprocessing
import json
import xgboost as xgb
from sklearn.model_selection import train_test_split
import pickle
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ###Read In Datasets

# %%
lib1720_path = '/content/drive/My Drive/Team Lambda/Data/2017-2019.csv'
lib19_path = '/content/drive/My Drive/Team Lambda/Data/2019.csv'
lib20_path = '/content/drive/My Drive/Team Lambda/Data/2020.csv'
lib17_path = '/content/drive/My Drive/Team Lambda/Data/2017.csv'
lib1417_path = '/content/drive/My Drive/Team Lambda/Data/2014-2017.csv'

# %%
nlp1720 = pd.read_csv(lib1720_path,encoding = "ISO-8859-1")

# %%
nlp19 = pd.read_csv(lib19_path, encoding = "ISO-8859-1")

# %%
nlp20 = pd.read_csv(lib20_path, encoding = "ISO-8859-1")

# %%
nlp17 = pd.read_csv(lib17_path, encoding = "ISO-8859-1")

# %%
nlp1417 = pd.read_csv(lib1417_path, encoding = "ISO-8859-1")

# %%
nlp20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 51 columns):
#  #   Column                                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                                 --------------  -----
#  0   Respondent ID                                                                                                                                          58 non-null     float64
#  1   Collector ID                                                                                                                                           58 non-null     float64
#  2   Start Date                                                                                                                                             58 non-null     object
#  3   End Date                                                                                                                                               58 non-null     object
#  4   Email Address                                                                                                                                          0 non-null      float64
#  5   First Name                                                                                                                                             0 non-null      float64
#  6   Last Name                                                                                                                                              0 non-null      float64
#  7   Custom Data 1                                                                                                                                          0 non-null      float64
#  8   Which bootcamp did you attend?                                                                                                                         55 non-null     object
#  9   One a scale of 1-10, 1 being lowest and 10 highest, how likely areåÊyou toåÊ recommend this course to others?                                          59 non-null     object
#  10  Unnamed: 10                                                                                                                                            28 non-null     object
#  11  I understood the goals and objectives of this course when it began:                                                                                    59 non-null     object
#  12  Unnamed: 12                                                                                                                                            9 non-null      object
#  13  The goals and objectives of this course, as I understand them, are met at this time:                                                                   59 non-null     object
#  14  Unnamed: 14                                                                                                                                            7 non-null      object
#  15  The requirements and grading system for the course were clear:                                                                                         59 non-null     object
#  16  Unnamed: 16                                                                                                                                            5 non-null      object
#  17  The instructors treated me with respect:                                                                                                               59 non-null     object
#  18  Unnamed: 18                                                                                                                                            15 non-null     object
#  19  The instructors were available to help when asked:                                                                                                     59 non-null     object
#  20  Unnamed: 20                                                                                                                                            11 non-null     object
#  21  The instructors were knowledgeable about the course material:                                                                                          59 non-null     object
#  22  Unnamed: 22                                                                                                                                            12 non-null     object
#  23  The instructors were organized and prepared:                                                                                                           59 non-null     object
#  24  Unnamed: 24                                                                                                                                            11 non-null     object
#  25  I am satisfied with the format of the instruction:                                                                                                     58 non-null     object
#  26  Unnamed: 26                                                                                                                                            14 non-null     object
#  27  The pace of the course was conducive to my learning:                                                                                                   59 non-null     object
#  28  Unnamed: 28                                                                                                                                            17 non-null     object
#  29  The level of the course material was conducive to my learning:                                                                                         59 non-null     object
#  30  Unnamed: 30                                                                                                                                            6 non-null      object
#  31  On average, how many hours per week have you spent, outside of the classroom, on this course?                                                          59 non-null     object
#  32  Unnamed: 32                                                                                                                                            10 non-null     object
#  33  Are there any changes you would recommend for this course?                                                                                             47 non-null     object
#  34  Did you have any concerns before beginning the bootcamp?                                                                                               59 non-null     object
#  35  Unnamed: 35                                                                                                                                            38 non-null     object
#  36  If you did have concerns before beginning the bootcamp, were those concerns alleviated?                                                                49 non-null     object
#  37  Unnamed: 37                                                                                                                                            29 non-null     object
#  38  Who challenged you the most?                                                                                                                           51 non-null     object
#  39  Who made you feel the most comfortable?                                                                                                                54 non-null     object
#  40  Who was your favorite guest instructor or speaker? Why?                                                                                                49 non-null     object
#  41  Who was your LEAST favorite guest instructor or speaker? Why?                                                                                          38 non-null     object
#  42  I had a good experience with myåÊBootcamp Success Manager (Sue):                                                                                       59 non-null     object
#  43  Unnamed: 43                                                                                                                                            15 non-null     object
#  44  I had a good experience with the Program Manager (Devonna):                                                                                            59 non-null     object
#  45  Unnamed: 45                                                                                                                                            12 non-null     object
#  46  I had a good experience with the Employer Relations Manager (Esteban):                                                                                 59 non-null     object
#  47  Unnamed: 47                                                                                                                                            13 non-null     object
#  48  The STEMulus Center provided an effective learning environment:                                                                                        57 non-null     object
#  49  Unnamed: 49                                                                                                                                            20 non-null     object
#  50  Would you like to leave a review about your bootcamp experience?åÊIf so, please write a short testimonial. It may be used for our marketing purposes.  31 non-null     object
# dtypes: float64(6), object(45)
# memory usage: 23.6+ KB

# %% [markdown]
# ##Data Cleaning

# %% [markdown]
# nlp17 and npl1417 data all comes from the fullstack web development couse. This information was not included in the datasets and so needed to be added.

# %%
nlp17['Which bootcamp did you attend?'] = 'Fullstack Web Development'
nlp1417['Which bootcamp did you attend?'] = 'Fullstack Web Development'

# %% [markdown]
# ###Synchronization of Column Names

# %% [markdown]
# To create unified column names that will adhere to each question, the column names for each dataset will be redefined. Below is a set of dictionaries that map the old column names to new codes that represent each unique question. The first two smaller dictionaries exist because some of the data sets share the same column names but they correspond to different questions. The two smaller dictionaries will change a few of the names on their respective datasets then the large dictionary will be ran on all datasets to produce unified column names.

# %%
column_names_mapped_nlp19 = {
    'Unnamed: 35': 'p14_s_r',
    'Unnamed: 43': 'qsue_r',
    'Unnamed: 47': 'qstem_r'
}

column_names_mapped_nlp20 = {
    'Unnamed: 35': 'p14_s_r',
    'Unnamed: 37': 'q14_1_r',
    'Unnamed: 43': 'qsue_r',
    'Unnamed: 47': 'qeste_r'
}

column_names_mapped_nlp1417 = {
    'Unnamed: 35': 'q_s_5_r',
    'Unnamed: 37': 'q_s_6_r'
}

column_names_mapped_nlp17 = {
    'Unnamed: 13': 'q4_r',
    'Unnamed: 15': 'q5_r',
    'Unnamed: 17': 'q6_r',
    'Unnamed: 19': 'q7_r',
    'Unnamed: 21': 'q8_r',
    'Unnamed: 29': 'q12_r',
    'Unnamed: 31': 'q1_r'
}

# %%
column_names_mapped = {
    'Which bootcamp did you attend?':'q1',
    'Would you recommend this course to others?':'q1_1',
    'Unnamed: 10':'q1_r',
    'I understood the goals and objectives of this course when it began:':'q2',
    'Unnamed: 12': 'q2_r',
    'The goals and objectives of this course, as I understand them, are met at this time:': 'q3',
    'Unnamed: 14': 'q3_r',
    'The requirements and grading system for the course were clear:': 'q4',
    'Unnamed: 16': 'q4_r',
    'The instructors treated me with respect:': 'q5',
    'Unnamed: 18': 'q5_r',
    'The instructors were available to help when asked:': 'q6',
    'Unnamed: 20': 'q6_r',
    'The instructors were knowledgeable about the course material:': 'q7',
    'Unnamed: 22': 'q7_r',
    'The instructors were organized and prepared:': 'q8',
    'Unnamed: 24': 'q8_r',
    'I am satisfied with the format of the instruction:': 'q9',
    'Unnamed: 26': 'q9_r',
    'The pace of the course was conducive to my learning:': 'q10',
    'Unnamed: 28': 'q10_r',
    'The level of the course material was conducive to my learning:': 'q11',
    'Unnamed: 30': 'q11_r',
    'On average, how many hours per week have you spent, outside of the classroom, on this course?': 'q12',
    'Unnamed: 32': 'q12_r',
    'Are there any changes you would recommend for this course?': 'q13_r',
    'Did you have any concerns before beginning the bootcamp and if so, were those concerns alleviated?': 'q14',
    'Unnamed: 35': 'q14_r',
    'Who challenged you the most?': 'q15_r',
    'Who made you feel the most comfortable?': 'q16_r',
    'Who was your favorite guest instructor or speaker? Why?': 'q17_r',
    'Who was your LEAST favorite guest instructor or speaker? Why?': 'q18_r',
    'I had a good experience with myåÊBootcamp Success Manager (Sue):': 'qsue',
    'Unnamed: 41': 'qsue_r',
    'I had a good experience withåÊmy Pro Dev instructor (Daniel):': 'qdan',
    'Unnamed: 43': 'qdan_r',
    'I had a good experience with the Program Manager (Devonna):': 'qdev',
    'Unnamed: 45': 'qdev_r',
    'The STEMulus Center provided an effective learning environment:': 'qstem',
    'Unnamed: 47': 'q22_r',
    'Would you like to leave a review about your bootcamp experience?åÊIf so, please write a short testimonial. It may be used for our marketing purposes.': 'q23_r',
    'One a scale of 1-10, 1 being lowest and 10 highest, how likely areåÊyou toåÊ recommend this course to others?':'q1_1',
    'Did you have any concerns before beginning the bootcamp?': 'q14_s',
    'If you did have concerns before beginning the bootcamp, were those concerns alleviated?': 'q14_1',
    'Unnamed: 37' : 'q14_1_1',
    'Respondent ID': 'Respondent ID',
    'Collector ID': 'Collector ID',
    'Start Date': 'Start Date',
    'End Date': 'End Date',
    'Email Address': 'Email Address',
    'First Name': 'First Name',
    'Last Name': 'Last Name',
    'Custom Data 1': 'Custom Data 1',
    'I had a good experience with the Employer Relations Manager (Esteban):': 'qeste',
    'Unnamed: 49':'qstem_r',
    'Unnamed: 9' : 'q2_r',
    'Unnamed: 11' : 'q3_r',
    'Unnamed: 13' : 'q5_r',
    'Unnamed: 15' : 'q4_r',
    'Unnamed: 17' : 'q_s_1_r',
    'Unnamed: 19' : 'q6_s_r',
    'Unnamed: 21' : 'q8_s_r',
    'Unnamed: 23' : 'q9_r',
    'Unnamed: 25' : 'q10_r',
    'Unnamed: 27' : 'q11_r',
    'Unnamed: 29' : 'q_s_2_r',
    'Unnamed: 31' : 'q_s_3_r',
    'Unnamed: 34' : 'q14_r',
    'I had a good experience with my Student Success Specialist (Karen):' : 'qkar',
    'Unnamed: 38' : 'qkar_r',
    'I had a good experience with my Career Coach (Daniel):' : 'qdan',
    'Unnamed: 40' : 'qdan_r',
    'I had a good experience with the Senior Program Manager (Andrea):' : 'qand',
    'Unnamed: 42' : 'qand_r',
    'Unnamed: 44' : 'qstem_r',
    'Would you like to leave a testimonial? If we may use it for marketing purposes, please include your name.åÊ' : 'q23_r',
    'I understood the goals/objective of this course at the beginning of the course:' : 'q2',
    'The goals/objective of this course, as I understand them, are met at this time:' : 'q3',
    'My instructor treated me with respect:' : 'q5',
    'I felt free to ask questions in the course:' : 'q_s_1',
    'The instructor answered my questions when I asked them:' : 'q6_s',
    "The instructor's course presentations were organized:" : 'q8_s',
    'The textbook helped me to learn:' : 'q_s_2',
    'Homework assignments helped me better understand the course material:' : 'q_s_3',
    'The instructor was willing to work with me outside of the class:' : 'q_s_4',
    'Unnamed: 33' : 'q_s_4_r',
    'The instructor evaluated my learning based on course material presented and course requirements:' : 'q_s_5',
    'I have become more competent in this area due to this course:' : 'q_s_6',
    'Unnamed: 39' : 'q12_r',
    'List one or more aspects of the course that you liked:' : 'q_s_7_r'

    }

# %% [markdown]
# The above dictionary needs to be checked for human error. To test the above dictionary we need to make sure that all current column names are mapped to their new code. The below function will affirm that all column names in a given column have a mapping and return any that have been missed.

# %%
def check_column_names(dataframe):
  """Check if all column names in dataframe are in the dictionary as keys."""

  output = []
  for column in dataframe.columns:
    if column in column_names_mapped:
      continue
    else:
      output.append(column)
  if len(output) == 0:
    return 'All column names are found in dictionary'
  else:
    return output

# %%
check_column_names(nlp1720)
# Out:
# 'All column names are found in dictionary'

# %%
check_column_names(nlp19)
# Out:
# 'All column names are found in dictionary'

# %%
check_column_names(nlp20)
# Out:
# 'All column names are found in dictionary'

# %%
check_column_names(nlp17)
# Out:
# 'All column names are found in dictionary'

# %%
check_column_names(nlp1417)
# Out:
# 'All column names are found in dictionary'

# %% [markdown]
# Rename the columns in all datasets using the above mapping.

# %%
nlp19.rename(column_names_mapped_nlp19, axis= 1, inplace=True)
nlp20.rename(column_names_mapped_nlp20, axis= 1, inplace=True)
nlp17.rename(column_names_mapped_nlp17, axis= 1, inplace=True)
nlp1417.rename(column_names_mapped_nlp1417, axis= 1, inplace=True)
nlp19.rename(column_names_mapped, axis= 1, inplace=True)
nlp20.rename(column_names_mapped, axis= 1, inplace=True)
nlp1720.rename(column_names_mapped, axis= 1, inplace=True)
nlp17.rename(column_names_mapped, axis= 1, inplace=True)
nlp1417.rename(column_names_mapped, axis= 1, inplace=True);

# %% [markdown]
# Check if all column names are mapped to codes.

# %%
print(nlp1720.columns)
print(nlp19.columns)
print(nlp20.columns)
print(nlp17.columns)
print(nlp1417.columns)
# Out:
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q1',
#        'q1_1', 'q1_r', 'q2', 'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r',
#        'q6', 'q6_r', 'q7', 'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r',
#        'q11', 'q11_r', 'q12', 'q12_r', 'q13_r', 'q14', 'q14_r', 'q15_r',
#        'q16_r', 'q17_r', 'q18_r', 'qsue', 'qsue_r', 'qdan', 'qdan_r', 'qdev',
#        'qdev_r', 'qstem', 'q22_r', 'q23_r'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q1',
#        'q1_1', 'q1_r', 'q2', 'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r',
#        'q6', 'q6_r', 'q7', 'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r',
#        'q11', 'q11_r', 'q12', 'q12_r', 'q13_r', 'q14_s', 'p14_s_r', 'q14_1',
#        'q14_1_1', 'q15_r', 'q16_r', 'q17_r', 'q18_r', 'qsue', 'qsue_r', 'qdev',
#        'qdev_r', 'qstem', 'qstem_r', 'q23_r'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q1',
#        'q1_1', 'q1_r', 'q2', 'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r',
#        'q6', 'q6_r', 'q7', 'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r',
#        'q11', 'q11_r', 'q12', 'q12_r', 'q13_r', 'q14_s', 'p14_s_r', 'q14_1',
#        'q14_1_r', 'q15_r', 'q16_r', 'q17_r', 'q18_r', 'qsue', 'qsue_r', 'qdev',
#        'qdev_r', 'qeste', 'qeste_r', 'qstem', 'qstem_r', 'q23_r'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q2',
#        'q2_r', 'q3', 'q3_r', 'q4', 'q4_r', 'q5', 'q5_r', 'q6', 'q6_r', 'q7',
#        'q7_r', 'q8', 'q8_r', 'q9', 'q9_r', 'q10', 'q10_r', 'q11', 'q11_r',
#        'q12', 'q12_r', 'q1_1', 'q1_r', 'q13_r', 'q14', 'q14_r', 'q15_r',
#        'q16_r', 'qkar', 'qkar_r', 'qdan', 'qdan_r', 'qand', 'qand_r', 'qstem',
#        'qstem_r', 'q23_r', 'q1'],
#       dtype='object')
# Index(['Respondent ID', 'Collector ID', 'Start Date', 'End Date',
#        'Email Address', 'First Name', 'Last Name', 'Custom Data 1', 'q2',
#        'q2_r', 'q3', 'q3_r', 'q5', 'q5_r', 'q4', 'q4_r', 'q_s_1', 'q_s_1_r',
#        'q6_s', 'q6_s_r', 'q8_s', 'q8_s_r', 'q9', 'q9_r', 'q10', 'q10_r', 'q11',
#        'q11_r', 'q_s_2', 'q_s_2_r', 'q_s_3', 'q_s_3_r', 'q_s_4', 'q_s_4_r',
#        'q_s_5', 'q_s_5_r', 'q_s_6', 'q_s_6_r', 'q12', 'q12_r', 'q_s_7_r',
#        'q13_r', 'q1'],
#       dtype='object')

# %% [markdown]
# Append the three data sets into one unified data frame.

# %%
combined_data = nlp1720.append([nlp19, nlp20, nlp17, nlp1417], ignore_index=True, sort=True)
combined_data.head()
# Out:
#    Collector ID  ...                                             qsue_r
# 0           NaN  ...                             Other (please specify)
# 1   175557115.0  ...  I am so happy Sue joined during our cohort! Sh...
# 2   175557115.0  ...                                                NaN
# 3   175557115.0  ...                                                NaN
# 4   175557115.0  ...                                    Sue's awesome.
#
# [5 rows x 78 columns]

# %%
combined_data.shape
# Out:
# (304, 78)

# %% [markdown]
# ###Delete Useles Columns and Rows

# %% [markdown]
# Drop unusable columns, and top row.

# %%
combined_data.drop(['Collector ID', 'Custom Data 1', 'Email Address', 'End Date', 'First Name', 'Last Name', 'Respondent ID', 'Start Date'], axis=1, inplace=True)

# %% [markdown]
# Drop unusable rows.

# %%
hedder_rows = combined_data[combined_data['q3']=='Response'].index

# %%
combined_data.drop(hedder_rows, axis=0, inplace=True)

# %% [markdown]
# Check

# %%
combined_data.reset_index(drop=True, inplace=True)

# %%
combined_data.head()
# Out:
#   p14_s_r  ...                                             qsue_r
# 0     NaN  ...  I am so happy Sue joined during our cohort! Sh...
# 1     NaN  ...                                                NaN
# 2     NaN  ...                                                NaN
# 3     NaN  ...                                    Sue's awesome.
# 4     NaN  ...                                                NaN
#
# [5 rows x 70 columns]

# %% [markdown]
# ###Pickle Data

# %%
combined_data_to_dict = combined_data.to_dict(orient='series')

# %%
pickle.dump(combined_data_to_dict, open('/content/drive/My Drive/Team Lambda/Pickled Files/to_be_cleaned.p', 'wb'))

# %%
to_be_cleaned_dict = pickle.load(open('/content/drive/My Drive/Team Lambda/Pickled Files/to_be_cleaned.p', 'rb'))

# %%
to_be_cleaned = pd.DataFrame.from_dict(to_be_cleaned_dict)

# %%
to_be_cleaned.head(3)
# Out:
#   p14_s_r  ...                                             qsue_r
# 0     NaN  ...  I am so happy Sue joined during our cohort! Sh...
# 1     NaN  ...                                                NaN
# 2     NaN  ...                                                NaN
#
# [3 rows x 70 columns]

# %%
combined_data.head(3)
# Out:
#   p14_s_r  ...                                             qsue_r
# 0     NaN  ...  I am so happy Sue joined during our cohort! Sh...
# 1     NaN  ...                                                NaN
# 2     NaN  ...                                                NaN
#
# [3 rows x 70 columns]

# %% [markdown]
# Deal with Nan values by creating a dataframe of empty strings and then overlaying all non Nan values from compbined_data into the new dataframe.

# %% [markdown]
# Creat an empty datframe.

# %%
new_df = pd.DataFrame(np.zeros(combined_data.shape), columns=combined_data.columns)

# %% [markdown]
# Replace values in zerow_df with a boolian indexed version of combined_data.

# %%
 new_df.update(combined_data)
 new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 70 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   p14_s_r  299 non-null    object
#  1   q1       299 non-null    object
#  2   q10      299 non-null    object
#  3   q10_r    299 non-null    object
#  4   q11      299 non-null    object
#  5   q11_r    299 non-null    object
#  6   q12      299 non-null    object
#  7   q12_r    299 non-null    object
#  8   q13_r    299 non-null    object
#  9   q14      299 non-null    object
#  10  q14_1    299 non-null    object
#  11  q14_1_1  299 non-null    object
#  12  q14_1_r  299 non-null    object
#  13  q14_r    299 non-null    object
#  14  q14_s    299 non-null    object
#  15  q15_r    299 non-null    object
#  16  q16_r    299 non-null    object
#  17  q17_r    299 non-null    object
#  18  q18_r    299 non-null    object
#  19  q1_1     299 non-null    object
#  20  q1_r     299 non-null    object
#  21  q2       299 non-null    object
#  22  q22_r    299 non-null    object
#  23  q23_r    299 non-null    object
#  24  q2_r     299 non-null    object
#  25  q3       299 non-null    object
#  26  q3_r     299 non-null    object
#  27  q4       299 non-null    object
#  28  q4_r     299 non-null    object
#  29  q5       299 non-null    object
#  30  q5_r     299 non-null    object
#  31  q6       299 non-null    object
#  32  q6_r     299 non-null    object
#  33  q6_s     299 non-null    object
#  34  q6_s_r   299 non-null    object
#  35  q7       299 non-null    object
#  36  q7_r     299 non-null    object
#  37  q8       299 non-null    object
#  38  q8_r     299 non-null    object
#  39  q8_s     299 non-null    object
#  40  q8_s_r   299 non-null    object
#  41  q9       299 non-null    object
#  42  q9_r     299 non-null    object
#  43  q_s_1    299 non-null    object
#  44  q_s_1_r  299 non-null    object
#  45  q_s_2    299 non-null    object
#  46  q_s_2_r  299 non-null    object
#  47  q_s_3    299 non-null    object
#  48  q_s_3_r  299 non-null    object
#  49  q_s_4    299 non-null    object
#  50  q_s_4_r  299 non-null    object
#  51  q_s_5    299 non-null    object
#  52  q_s_5_r  299 non-null    object
#  53  q_s_6    299 non-null    object
#  54  q_s_6_r  299 non-null    object
#  55  q_s_7_r  299 non-null    object
#  56  qand     299 non-null    object
#  57  qand_r   299 non-null    float64
#  58  qdan     299 non-null    object
#  59  qdan_r   299 non-null    object
#  60  qdev     299 non-null    object
#  61  qdev_r   299 non-null    object
#  62  qeste    299 non-null    object
#  63  qeste_r  299 non-null    object
#  64  qkar     299 non-null    object
#  65  qkar_r   299 non-null    float64
#  66  qstem    299 non-null    object
#  67  qstem_r  299 non-null    object
#  68  qsue     299 non-null    object
#  69  qsue_r   299 non-null    object
# dtypes: float64(2), object(68)
# memory usage: 163.6+ KB

# %% [markdown]
# ##Exploratory Data Analysis

# %%
nlp20[0:2]
# Out:
#    Respondent ID  ...                q23_r
# 0            NaN  ...  Open-Ended Response
# 1   1.173612e+10  ...                  NaN
#
# [2 rows x 51 columns]

# %%
nlp1720.shape
# Out:
# (154, 49)

# %%
nlp19.shape
# Out:
# (35, 49)

# %%
nlp20.shape
# Out:
# (59, 51)

# %% [markdown]
# ###Bootcamp Distribution --- Done

# %%
column_names_mapped['Which bootcamp did you attend?']
# Out:
# 'q1'

# %%
#Bootcamp set
a=nlp1720['q1'].value_counts()
b=nlp19['q1'].value_counts()
c=nlp20['q1'].value_counts()

# %%
#Concatenate all three lists together
bootcamps=pd.concat([a, b, c], axis=1)

# %%
# Replace NAN and get total responses for each bootcamp
bootcamps=bootcamps.fillna(0)
bootcamps.loc[:,'Total']=bootcamps.sum(axis=1)

# %%
# Cleanup result
bootcamps_clean=bootcamps.drop(['q1'], axis=1, inplace=True)
bootcamps=bootcamps.drop(labels=['Response'], axis=0)

# %%
bootcamps
# Out:
#                            Total
# Fullstack Web Development  126.0
# Java+Android                74.0
# Digital Media               29.0
# Microsoft .NET               3.0
# Internet of Things (IoT)     5.0
# Data Science                 3.0

# %% [markdown]
# ### Addressing "Recommend" Responses

# %% [markdown]
# Given the three datasets: nlp1720, nlp19, nlp20, there was a change to how responses were requested from binary (Y,N) to a Likert scale (1 - 10) for the question "Would you recommend this course to others?"
#
# To address these differences it was decided to collapse the Likert scale into a Binary pattern.
#
# |Likert Scale <br>value| Binary <br>value|
# |-|-|
# | <=5 | N |
# | >5 | Y|
#
# To apply, a function will be constructed to perform the translation.

# %% [markdown]
# ##Function to convert Likert to Binary

# %% [markdown]
# Determining distribution of responses on question
# nlp1720: q1_1

# %%
column_names_mapped['Would you recommend this course to others?']
# Out:
# 'q1_1'

# %%
nlp1720['q1_1'].value_counts()
# Out:
# Yes         143
# No            8
# Response      1
# Name: q1_1, dtype: int64

# %%
column_names_mapped['One a scale of 1-10, 1 being lowest and 10 highest, how likely areåÊyou toåÊ recommend this course to others?']
# Out:
# 'q1_1'

# %%
nlp19['q1_1'].value_counts()
# Out:
# 10          14
# 9            9
# 8            5
# 7            3
# 4            1
# Response     1
# 2            1
# Name: q1_1, dtype: int64

# %%
nlp20['q1_1'].value_counts()
# Out:
# 10          32
# 9           10
# 8            8
# 7            3
# 3            3
# Response     1
# 6            1
# 5            1
# Name: q1_1, dtype: int64

# %%
#review specific NO responses
nlp1720[nlp1720['q1_1']=='No']
# Out:
#      Respondent ID  ...                                              q23_r
# 44    6.997736e+09  ...                                                NaN
# 47    6.997480e+09  ...                                                NaN
# 69    6.967738e+09  ...  I know I was harsh with some of my commits. I ...
# 74    6.967735e+09  ...                                                NaN
# 86    6.967693e+09  ...  I was stuck in minimum wage jobs and was start...
# 122   6.825121e+09  ...  I like to see a few engineering boot camp in t...
# 134   6.762600e+09  ...  There is so much potential here. If the bridge...
# 138   6.630802e+09  ...                                                NaN
#
# [8 rows x 49 columns]

# %%
# review low - below 5 responses
nlp19[nlp19['q1_1']=='4']
# Out:
#     Respondent ID  Collector ID     Start Date  ...    qstem  qstem_r  q23_r
# 23   1.120203e+10   247716749.0  12/6/19 10:51  ...  Neutral      NaN    NaN
#
# [1 rows x 49 columns]

# %%
nlp20[nlp20['q1_1']=='5']
# Out:
#     Respondent ID  ...                                              q23_r
# 10   1.172508e+10  ...  Like all education it's way over priced by at ...
#
# [1 rows x 51 columns]

# %% [markdown]
# ##Data Proccessing

# %% [markdown]
# ##Data Visualization
